# %% [markdown]
# # [La librairie H3](https://h3geo.org/docs/)

# %% [markdown]
# ### 0. installation des packages si nécessaire
#
# Le point d'exclamation est pour rendre opérationnel aux commandes shell

# %% [markdown]
# ## 1. Utilisation de pandas pour gérer les données de population

# %%
import pandas as pd

# %% [markdown]
# ### on se propose de travailler sur l'année 2010

# %%
# un jeu de données présent dans le répertoire courant
dataset = pd.read_csv("popfr19752010.csv")

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# + reg : code region INSEE (character)
# + dep : code departement INSEE (character, corse 201 et 202 au lieu de 2A et 2B)
# + com : code commune INSEE (character)
# + article : article du nom de la commune (character)
# + com_nom : nom de la commune (character)
# + long : longitude (numeric)
# + lat : latitude (numeric)
# + pop_i : estimation de la population à la date i (ramenée à 1 si <=0), i=1975,…,2010 (numeric)

# %%
dataset.head()
# Out:
#    reg  dep  com article                     com_nom      long        lat  \
# 0   11   75   56     NaN                       PARIS  2.352222  48.856614
# 1   11   77    1     NaN            ACHERES-LA-FORET  2.570289  48.354976
# 2   11   77   10     NaN  AUBEPIERRE-OZOUER-LE-REPOS  2.890552  48.632323
# 3   11   77  100      LE            CHATELET-EN-BRIE  2.792095  48.504945
# 4   11   77  101     NaN          CHATENAY-SUR-SEINE  3.096229  48.418774
#
#        pop_1975      pop_1976      pop_1977  ...      pop_2001      pop_2002  \
# 0  2.294116e+06  2.277408e+06  2.261510e+06  ...  2.142425e+06  2.149205e+06
# 1  6.482592e+02  6.620875e+02  6.763429e+02  ...  1.106389e+03  1.126294e+03
# 2  5.874394e+02  5.995405e+02  6.118238e+02  ...  8.738642e+02  8.797754e+02
# 3  2.251402e+03  2.481846e+03  2.695300e+03  ...  4.408286e+03  4.407891e+03
# 4  5.071603e+02  5.391894e+02  5.699313e+02  ...  9.284420e+02  9.278621e+02
#
#        pop_2003      pop_2004      pop_2005      pop_2006      pop_2007  \
# 0  2.156989e+06  2.165785e+06  2.175600e+06  2.186440e+06  2.198315e+06
# 1  1.146224e+03  1.166163e+03  1.186095e+03  1.206006e+03  1.225880e+03
# 2  8.849946e+02  8.894883e+02  8.932229e+02  8.961646e+02  8.982798e+02
# 3  4.407379e+03  4.407398e+03  4.408599e+03  4.411630e+03  4.417140e+03
# 4  9.260636e+02  9.230492e+02  9.188215e+02  9.133832e+02  9.067369e+02
#
#        pop_2008      pop_2009      pop_2010
# 0  2.211230e+06  2.225194e+06  2.240213e+06
# 1  1.245702e+03  1.265455e+03  1.285127e+03
# 2  8.995351e+02  8.998966e+02  8.993365e+02
# 3  4.425779e+03  4.438194e+03  4.454928e+03
# 4  8.988853e+02  8.898310e+02  8.795762e+02
#
# [5 rows x 43 columns]

# %%
# description générale
dataset.describe()
# Out:
#                 reg           dep           com          long           lat  \
# count  36318.000000  36318.000000  36318.000000  36318.000000  36318.000000
# mean      49.644969     47.574453    251.244755      2.732537     46.973237
# std       25.363154     29.592749    180.946130      2.657415      2.210865
# min       11.000000      1.000000      1.000000     -5.097626     41.387174
# 25%       25.000000     25.000000    106.000000      0.666670     45.164214
# 50%       43.000000     49.000000    218.000000      2.624225     47.390142
# 75%       73.000000     67.000000    361.000000      4.850849     48.836580
# max       94.000000    202.000000    909.000000      9.530300     51.070883
#
#            pop_1975      pop_1976      pop_1977      pop_1978      pop_1979  \
# count  3.631800e+04  3.631800e+04  3.631800e+04  3.631800e+04  3.631800e+04
# mean   1.446755e+03  1.455133e+03  1.463207e+03  1.470994e+03  1.478521e+03
# std    1.488296e+04  1.477034e+04  1.466529e+04  1.456763e+04  1.447717e+04
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.657071e+02  1.665941e+02  1.677070e+02  1.682949e+02  1.688806e+02
# 50%    3.338508e+02  3.381541e+02  3.414386e+02  3.439452e+02  3.462345e+02
# 75%    7.528022e+02  7.620948e+02  7.759058e+02  7.876871e+02  7.996927e+02
# max    2.294116e+06  2.277408e+06  2.261510e+06  2.246430e+06  2.232175e+06
#
#        ...      pop_2001      pop_2002      pop_2003      pop_2004  \
# count  ...  3.631800e+04  3.631800e+04  3.631800e+04  3.631800e+04
# mean   ...  1.635056e+03  1.644360e+03  1.654080e+03  1.664244e+03
# std    ...  1.412941e+04  1.418188e+04  1.423971e+04  1.430282e+04
# min    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    ...  1.795870e+02  1.810448e+02  1.824686e+02  1.841070e+02
# 50%    ...  3.907489e+02  3.945034e+02  3.982375e+02  4.029527e+02
# 75%    ...  9.554295e+02  9.662275e+02  9.766085e+02  9.846889e+02
# max    ...  2.142425e+06  2.149205e+06  2.156989e+06  2.165785e+06
#
#            pop_2005      pop_2006      pop_2007      pop_2008      pop_2009  \
# count  3.631800e+04  3.631800e+04  3.631800e+04  3.631800e+04  3.631800e+04
# mean   1.674881e+03  1.686018e+03  1.697685e+03  1.709908e+03  1.722717e+03
# std    1.437118e+04  1.444478e+04  1.452361e+04  1.460770e+04  1.469710e+04
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.858505e+02  1.877576e+02  1.895702e+02  1.917419e+02  1.938557e+02
# 50%    4.069628e+02  4.111323e+02  4.160923e+02  4.213762e+02  4.273289e+02
# 75%    9.968289e+02  1.008801e+03  1.022184e+03  1.035528e+03  1.049666e+03
# max    2.175600e+06  2.186440e+06  2.198315e+06  2.211230e+06  2.225194e+06
#
#            pop_2010
# count  3.631800e+04
# mean   1.736135e+03
# std    1.479191e+04
# min    1.000000e+00
# 25%    1.957946e+02
# 50%    4.326952e+02
# 75%    1.065215e+03
# max    2.240213e+06
#
# [8 rows x 41 columns]

# %%
# recherche des entêtes
dataset.shape
# Out:
# (36318, 43)

# %%
import random
reg_unique = pd.unique(dataset['reg'])

# %%
reg_unique
# Out:
# array([11, 21, 22, 23, 24, 25, 26, 31, 41, 42, 43, 52, 53, 54, 72, 73, 74,
#        82, 83, 91, 93, 94])

# %%
random.choice(reg_unique)
# Out:
# 26

# %%
rand_df = dataset.loc[dataset['reg'] == random.choice(reg_unique)]

# %%
rand_df
# Out:
#        reg  dep  com article      com_nom      long        lat     pop_1975  \
# 32154   83   15    1     NaN     ALLANCHE  2.934557  45.229086  1393.976889
# 32155   83   15   10     NaN       ARCHES  2.327730  45.307756   210.376596
# 32156   83   15  100     NaN  LAVEISSENET  2.890356  45.082092   150.062685
# 32157   83   15  101     NaN  LAVEISSIERE  2.807289  45.116424   588.635117
# 32158   83   15  102     NaN    LAVIGERIE  2.748695  45.138957   180.795573
# ...    ...  ...  ...     ...          ...       ...        ...          ...
# 33457   83   63   95     NaN      CHARNAT  3.431988  45.944040   227.278413
# 33458   83   63   96     NaN         CHAS  3.301510  45.748646   221.565076
# 33459   83   63   97     NaN    CHASSAGNE  3.077313  45.497850   143.703919
# 33460   83   63   98     NaN    CHASTREIX  2.735682  45.512075   504.212653
# 33461   83   63   99     NaN   CHATEAUGAY  3.085507  45.850891  2099.801109
#
#           pop_1976     pop_1977  ...     pop_2001     pop_2002     pop_2003  \
# 32154  1377.940558  1362.785656  ...  1062.053609  1043.754058  1024.321507
# 32155   207.928213   205.486652  ...   172.945967   173.676240   174.653438
# 32156   149.326120   148.339641  ...    97.107550    95.800437    94.717588
# 32157   596.302364   602.851939  ...   580.015465   578.032653   576.484922
# 32158   175.606769   170.568998  ...   101.362404   100.899203   100.650934
# ...            ...          ...  ...          ...          ...          ...
# 33457   226.996724   226.575421  ...   200.979075   200.367311   199.879925
# 33458   221.479193   221.679029  ...   318.300814   326.407392   334.860791
# 33459   139.390308   135.528775  ...   108.843210   107.579591   106.071726
# 33460   491.788393   479.616689  ...   271.892750   267.113714   262.673535
# 33461  2176.430258  2249.006627  ...  3066.590858  3074.295892  3080.863997
#
#           pop_2004     pop_2005     pop_2006     pop_2007     pop_2008  \
# 32154  1003.678477   981.747492   958.451073   933.711742   907.452021
# 32155   175.886797   177.385551   179.158934   181.216183   183.566530
# 32156    93.877242    93.297635    92.997006    92.993592    93.305631
# 32157   575.431993   574.933587   575.049426   575.839231   577.362723
# 32158   100.620055   100.809023   101.220297   101.856333   102.719589
# ...            ...          ...          ...          ...          ...
# 33457   199.527070   199.318899   199.265565   199.377223   199.664025
# 33458   343.663362   352.817455   362.325420   372.189606   382.412365
# 33459   104.292833   102.216130    99.814836    97.062170    93.931348
# 33460   258.575533   254.823026   251.419335   248.367777   245.671674
# 33461  3086.407324  3091.038020  3094.868232  3098.010110  3100.575801
#
#           pop_2009     pop_2010
# 32154   879.594432   850.074411
# 32155   186.219212   189.181924
# 32156    93.951361    94.945979
# 32157   579.679623   582.839699
# 32158   103.812523   105.137184
# ...            ...          ...
# 33457   200.136126   200.801986
# 33458   392.996046   403.942608
# 33459    90.395591    86.432578
# 33460   243.334343   241.358552
# 33461  3102.677454  3104.408525
#
# [1308 rows x 43 columns]

# %%
dataset2010 = rand_df[['com_nom', 'lat', 'long', 'pop_2010']]

# %%
dataset2010
# Out:
#            com_nom        lat      long     pop_2010
# 32154     ALLANCHE  45.229086  2.934557   850.074411
# 32155       ARCHES  45.307756  2.327730   189.181924
# 32156  LAVEISSENET  45.082092  2.890356    94.945979
# 32157  LAVEISSIERE  45.116424  2.807289   582.839699
# 32158    LAVIGERIE  45.138957  2.748695   105.137184
# ...            ...        ...       ...          ...
# 33457      CHARNAT  45.944040  3.431988   200.801986
# 33458         CHAS  45.748646  3.301510   403.942608
# 33459    CHASSAGNE  45.497850  3.077313    86.432578
# 33460    CHASTREIX  45.512075  2.735682   241.358552
# 33461   CHATEAUGAY  45.850891  3.085507  3104.408525
#
# [1308 rows x 4 columns]

# %% [markdown]
# ### 1.1 on se construit un dataset pour l'année 2010

# %%
dataset2010.head()
# Out:
#            com_nom        lat      long    pop_2010
# 32154     ALLANCHE  45.229086  2.934557  850.074411
# 32155       ARCHES  45.307756  2.327730  189.181924
# 32156  LAVEISSENET  45.082092  2.890356   94.945979
# 32157  LAVEISSIERE  45.116424  2.807289  582.839699
# 32158    LAVIGERIE  45.138957  2.748695  105.137184

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: pillow>=8 in ./lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./lib/python3.10/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.21 in ./lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: cycler>=0.10 in ./lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Dessin standard : tous les points centraux des communes (il y en a beaucoup)
dataset2010.plot(x='long',y='lat',style='.',alpha=0.2,figsize=(12,12));

# %% [markdown]
# ### dessin avec matplotlib

# %%
import numpy as np
#import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,12))
plt.scatter(dataset2010['long'], dataset2010['lat'], dataset2010['pop_2010']*0.0001, alpha=0.5)
plt.show()

# %% [markdown]
# ## 2. Introduction de la librairie H3

# %%
import h3

# %%
# démonstration et vérification que H3 fonctionne réellement ; impression attendue '831f90fffffffff'
lat, lng, res= 48.5, 2.20, 3
h3.geo_to_h3(lat, lng, res)
# Out:
# '831fb0fffffffff'

# %%
lat, lng, res= 48.5, 2.20, 7
h3.geo_to_h3(lat, lng, res)
# Out:
# '871fb0d13ffffff'

# %% [markdown]
# ### examen de la fonction `geo_to_h3(coords, res = 7)`
#
# + coords : numeric vector, matrix or data.frame with [lat, lng] pairs; object of class sf (geometry type: POINT)
# + res	: resolution of hexagons to return; number between 0 and 15

# %%
######### Temps pour l'utilisation réelle de H3 avec l'ensemble de données #########

# %% [markdown]
# 3 concepts: geoserie, **apply**, fonction anonyme, **assign**
#
# + une dataframe de geopandas est composée de geoserie
# + avec la méthodes `apply` on va créer une geoserie contenant les H3-index, en itérant ligne par ligne sur la dataframe
# + [fonction anonyme lambda](https://www.w3schools.com/python/python_lambda.asp) , la syntaxe est lambda row: h3.geo_to_h3(row.lat, row.long, resolution)
# + avec la méthode `assign` on rajoute une colonne.

# %%
# pour tous les points de données avec lat/long, nous ajoutons l'hex_id correspondant 
#(pas unique ici, plusieurs communes tomberont dans le même hexagone)

# valeurs pour résolution plus petite = hexagones plus grands ; 
#quelque chose comme 3-6 est une fourchette raisonnable.
resolution = 5

# on crée une géo série avec apply à partir de la dataframe + 
hex_ids = dataset2010.apply(lambda row: h3.geo_to_h3(row.lat, row.long, resolution), axis = 1)
dataset2010 = dataset2010.assign(hex_id=hex_ids.values)

# %%
hex_ids
# Out:
# 32154    851f9663fffffff
# 32155    851f9643fffffff
# 32156    851f966bfffffff
# 32157    851f966bfffffff
# 32158    851f966bfffffff
#               ...
# 33457    851f90d3fffffff
# 33458    851f9637fffffff
# 33459    851f963bfffffff
# 33460    851f960ffffffff
# 33461    851f96a3fffffff
# Length: 1308, dtype: object

# %%
# index non unique
hex_ids.nunique()
# Out:
# 137

# %% [markdown]
# ##### méthode nunique() : Return number of unique elements in the object.

# %%
dataset2010["hex_id"].nunique()
# Out:
# 137

# %%
# additionner les populations par hex_id
dataset2010byhexid = dataset2010.groupby("hex_id", as_index=False).agg({"pop_2010": "sum"})

# %%
dataset2010byhexid.columns = ["hex_id", "value"]
dataset2010byhexid
# Out:
#               hex_id         value
# 0    85186da3fffffff   1276.401256
# 1    85186da7fffffff   1198.573090
# 2    85186db3fffffff   2521.378036
# 3    85186db7fffffff  63384.409374
# 4    85186dbbfffffff    193.211088
# ..               ...           ...
# 132  853965abfffffff   4365.717911
# 133  853965affffffff    607.524354
# 134  853965b3fffffff   9415.349838
# 135  853965b7fffffff   2424.193358
# 136  853965bbfffffff  12382.609407
#
# [137 rows x 2 columns]

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in ./lib/python3.10/site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in ./lib/python3.10/site-packages (from scipy) (1.26.2)

# %%
# cartographier les populations par hexagone en centiles à la place, afin de s'assurer que nous utilisons bien notre gamme de couleurs !
import scipy.stats as scs

# %% [markdown]
# + Percentile
# + Liste en compréhension

# %%
dataset2010byhexid["centile"] = [scs.percentileofscore(dataset2010byhexid["value"].values, i)\
                                 for i in dataset2010byhexid["value"].values]

# %% [markdown]
# #### à propos du centile :

# %%
dataset2010byhexid
# Out:
#               hex_id         value    centile
# 0    85186da3fffffff   1276.401256  21.167883
# 1    85186da7fffffff   1198.573090  20.437956
# 2    85186db3fffffff   2521.378036  32.846715
# 3    85186db7fffffff  63384.409374  98.540146
# 4    85186dbbfffffff    193.211088   1.459854
# ..               ...           ...        ...
# 132  853965abfffffff   4365.717911  51.824818
# 133  853965affffffff    607.524354   8.759124
# 134  853965b3fffffff   9415.349838  77.372263
# 135  853965b7fffffff   2424.193358  32.116788
# 136  853965bbfffffff  12382.609407  83.211679
#
# [137 rows x 3 columns]

# %%
# avons-nous vraiment besoin de les trier ?
dataset2010byhexid.sort_values(by = "value", ascending = False, inplace = True)
dataset2010byhexid
# Out:
#               hex_id          value     centile
# 119  851f96abfffffff  196266.518375  100.000000
# 120  851f96affffffff   88766.729436   99.270073
# 3    85186db7fffffff   63384.409374   98.540146
# 117  851f96a3fffffff   52818.542265   97.810219
# 73   851f946bfffffff   52366.798858   97.080292
# ..               ...            ...         ...
# 57   851f9417fffffff     380.232093    3.649635
# 23   851f9203fffffff     313.099828    2.919708
# 10   851f9057fffffff     222.720718    2.189781
# 4    85186dbbfffffff     193.211088    1.459854
# 15   851f9097fffffff     150.729941    0.729927
#
# [137 rows x 3 columns]

# %% [markdown]
# ## 3. introduction de folium

# %%
# !pip install folium geojson
# Out:
# Requirement already satisfied: folium in ./lib/python3.10/site-packages (0.15.0)
# Requirement already satisfied: geojson in ./lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: requests in ./lib/python3.10/site-packages (from folium) (2.31.0)
# Requirement already satisfied: numpy in ./lib/python3.10/site-packages (from folium) (1.26.2)
# Requirement already satisfied: jinja2>=2.9 in ./lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in ./lib/python3.10/site-packages (from folium) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.10/site-packages (from requests->folium) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests->folium) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.10/site-packages (from requests->folium) (3.3.2)

# %%
import folium
from geojson import Feature, Point, FeatureCollection
import json

# %% [markdown]
# ### 3.3 fonction qui crée un fichier geojson

# %%
def hexagons_dataframe_to_geojson(df_hex, file_output = None, column_name = "value"):
    """
    Produire le GeoJSON pour un dataframe, en précisant la géométrie à partir de la colonne "hex_id".
    et avec une propriété correspondant à celle de column_name
    """    
    list_features = []
    
    for i,row in df_hex.iterrows():
        try:
            geometry_for_row = { "type" : "Polygon", "coordinates": \
                                [h3.h3_to_geo_boundary(h=row["hex_id"],geo_json=True)]}
            feature = Feature(geometry = geometry_for_row , id=row["hex_id"], \
                              properties = {column_name : row[column_name]})
            list_features.append(feature)
        except:
            print("An exception occurred for hex " + row["hex_id"]) 

    feat_collection = FeatureCollection(list_features)
    geojson_result = json.dumps(feat_collection)
    return geojson_result

# %% [markdown]
# ### 3.2 fonction pour recupérer une couleur
#
# + revoir les colormap de matplotlib
# + [Explications sur colormap](https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
# cm c'est pour clormap
def get_color(custom_cm, val, vmin, vmax):
    return matplotlib.colors.to_hex(custom_cm((val-vmin)/(vmax-vmin)))

# %% [markdown]
# ### 3.3 fonction qui crée une choropleth à partir de données agrégées

# %%
def choropleth_map(df_aggreg, column_name = "value", border_color = 'black',\
                   fill_opacity = 0.7, color_map_name = "Blues", initial_map = None):
    """
    Creates choropleth maps given the aggregated data. initial_map can be an existing map to draw on top of.
    """    
    #colormap
    min_value = df_aggreg[column_name].min()
    max_value = df_aggreg[column_name].max()
    mean_value = df_aggreg[column_name].mean()
    print(f"valeur min pour la couleur= {min_value}, valeur max= {max_value}, \
            valeur moyenne= {mean_value}")
    print(f"décompte des cellules hexagonales : {df_aggreg['hex_id'].nunique()}")
    
    # the name of the layer just needs to be unique, put something silly there for now:
    name_layer = "Choropleth " + str(df_aggreg)
    
    # on choisit un fond de carte si l'appel de la fonction n'en précise pas
    if initial_map is None:
        initial_map = folium.Map(location= [47, 4], zoom_start=5.5, tiles="cartodb dark_matter")
    
    # fichier geojson crée à partie de la df
    #create geojson data from dataframe
    geojson_data = hexagons_dataframe_to_geojson(df_hex = df_aggreg, column_name = column_name)

    # on peut choisir une gamme de couleur à partir de nombreuses possibilité
    # color_map_name 'Blues' for now, many more at https://matplotlib.org/stable/tutorials/colors/colormaps.html to choose from!
    custom_cm = matplotlib.cm.get_cmap(color_map_name)

    folium.GeoJson(
        geojson_data,
        style_function=lambda feature: {
            'fillColor': get_color(custom_cm, feature['properties'][column_name], vmin=min_value, vmax=max_value),
            'color': border_color,
            'weight': 1,
            'fillOpacity': fill_opacity 
        }, 
        name = name_layer
    ).add_to(initial_map)

    return initial_map

# %%
hexmap = choropleth_map(df_aggreg = dataset2010byhexid, color_map_name = "Blues", column_name = "value")
hexmap
# Out:
# valeur min pour la couleur= 150.729941470979, valeur max= 196266.51837517388,             valeur moyenne= 9898.232130398399
# décompte des cellules hexagonales : 137
# /tmp/ipykernel_16868/793647984.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   custom_cm = matplotlib.cm.get_cmap(color_map_name)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e94c994fea0bbd9c183f7ed403f12eb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e94c994fea0bbd9c183f7ed403f12eb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e94c994fea0bbd9c183f7ed403f12eb4 = L.map(
#                 &quot;map_e94c994fea0bbd9c183f7ed403f12eb4&quot;,
#                 {
#                     center: [47.0, 4.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0300fe3ff35f80cebbc1f9d55cbaca85 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_0300fe3ff35f80cebbc1f9d55cbaca85.addTo(map_e94c994fea0bbd9c183f7ed403f12eb4);
#
#         function geo_json_63a01d0a0af2f743c7d737aeb72a3fd4_styler(feature) {
#             switch(feature.id) {
#                 case &quot;851f96abfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08306b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96affffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fb9da&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186db7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#afd1e7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96a3fffffff&quot;: case &quot;851f946bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c1d9ed&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f92abfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c2d9ee&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9403fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#cadef0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9633fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#cee0f2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;853965a3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d0e1f2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f906bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d1e2f3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9623fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9e8f5&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9637fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#deebf7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f90c3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e1edf8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f962ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e3eef8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f946ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e3eef9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f90dbfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e4eff9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f92a7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e7f0fa&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9463fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e7f1fa&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96b7fffffff&quot;: case &

# %% [markdown]
# on a 2435 hexagones

# %% [markdown]
#  On modifie la colormap, cela change les couleurs , et on utilise une autre colonne, celle des centiles, pour régler ces couleurs.
#
#  [centile et percentile](https://datascience.eu/fr/mathematiques-et-statistiques/percentiles-rang-de-percentile-et-intervalle-de-percentile-definition-et-exemples/)

# %%
hexmap = choropleth_map(df_aggreg = dataset2010byhexid, color_map_name = "YlOrRd", column_name = "centile")
hexmap
# Out:
# valeur min pour la couleur= 0.7299270072992701, valeur max= 100.0,             valeur moyenne= 50.36496350364963
# décompte des cellules hexagonales : 137
# /tmp/ipykernel_16868/793647984.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   custom_cm = matplotlib.cm.get_cmap(color_map_name)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fdceaecc6456d238ab0b932f77901fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fdceaecc6456d238ab0b932f77901fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fdceaecc6456d238ab0b932f77901fe = L.map(
#                 &quot;map_2fdceaecc6456d238ab0b932f77901fe&quot;,
#                 {
#                     center: [47.0, 4.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a175be28472d6c87310bd8c935ba3aa5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a175be28472d6c87310bd8c935ba3aa5.addTo(map_2fdceaecc6456d238ab0b932f77901fe);
#
#         function geo_json_e2fd421172b8e1220fac51ef611af882_styler(feature) {
#             switch(feature.id) {
#                 case &quot;851f96abfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#800026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96affffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#820026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186db7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#860026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96a3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8a0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f946bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8d0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f92abfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#910026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9403fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#950026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9633fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#990026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;853965a3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9d0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f906bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9f0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9623fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a20026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9637fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a60026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f90c3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#aa0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f962ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ae0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f946ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b20026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f90dbfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b60026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f92a7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b90026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9463fffffff&quot;:
#                     return {&quot;color

# %% [markdown]
# ## 2. fusion de cellules ou  compacticité pour les cellules

# %%
# également, une autre expérience amusante : H3 peut compacter un ensemble de cellules 
# pour utiliser des cellules plus grandes lorsque cela est possible.
# La réversibilité de cette opération est garantie car elle opère au niveau des cellules, 
# qui ont toujours un seul parent.
# (même lorsqu'elles n'entrent pas complètement dans le cadre d'une cellule parentale possible).

# %%
compactedCells = h3.compact(dataset2010byhexid['hex_id'])

# %%
type(compactedCells)
""" on construit un ensemble dont la cardinalité est moindre"""
# Out:
# ' on construit un ensemble dont la cardinalité est moindre'

# %% [markdown]
# Compactification de cellules --> construit une liste de cellules

# %%
# nous avons commencé avec ce nombre de cellules...
dataset2010byhexid['hex_id'].nunique()
# Out:
# 137

# %%
# et ils ont été réduits à ce nombre :
len(compactedCells)
# Out:
# 71

# %%
# on fait une copie
dataset2010byhexid_compacted = dataset2010byhexid.copy()

# %%
type(dataset2010byhexid_compacted)
dataset2010byhexid_compacted
# Out:
#               hex_id          value     centile
# 119  851f96abfffffff  196266.518375  100.000000
# 120  851f96affffffff   88766.729436   99.270073
# 3    85186db7fffffff   63384.409374   98.540146
# 117  851f96a3fffffff   52818.542265   97.810219
# 73   851f946bfffffff   52366.798858   97.080292
# ..               ...            ...         ...
# 57   851f9417fffffff     380.232093    3.649635
# 23   851f9203fffffff     313.099828    2.919708
# 10   851f9057fffffff     222.720718    2.189781
# 4    85186dbbfffffff     193.211088    1.459854
# 15   851f9097fffffff     150.729941    0.729927
#
# [137 rows x 3 columns]

# %% [markdown]
# # rappel sur fonctions récursives, analyse de la  conception

# %%
# given hex id hid, find out if it already exists in setOfHexes, or if not, recursively check if the parent does
# (to a max level of 4, for now)
# pour un hexagone donné, vérifier s'il existe déjà dans setOfHexes, ou si ce n'est pas le cas, vérifier récursivement si le parent existe.
# (jusqu'à un niveau maximum de 4, pour l'instant)

# there must be a simpler way of doing this with built-in h3 functionality?

# fonction récursive
def findSmallestInSet(hid, setOfHexes, depth=0):
    # si on trouve le hid on le retourne
    if hid in setOfHexes or depth > 4:
        return hid
    else:
        # sinon on on cherche le parent, récursivement
        parentHex = h3.h3_to_parent(hid)
        return findSmallestInSet(parentHex, setOfHexes, depth=depth+1)

# %%
# translate the hex ids we had to whatever larger hex id they are a part of, from the compacted set
# traduire les identifiants hexagonaux que nous avions en un identifiant hexagonal plus grand dont ils font partie, à partir de l'ensemble compacté

dataset2010byhexid_compacted['hex_id'] = \
  dataset2010byhexid_compacted['hex_id'].map(lambda hid: findSmallestInSet(hid, compactedCells, depth=0))

# %%
# puisque nous avons changé les hex ids maintenant, nous devons recalculer les valeurs de population ou de clacul
# (prenons la moyenne, bien qu'elle puisse ne pas être une valeur significative dans ce cas, étant une moyenne de percentiles)
dataset2010byhexid_compacted = dataset2010byhexid_compacted.groupby('hex_id', as_index=False).agg({"centile": "mean"})

# %%
dataset2010byhexid_compacted
# Out:
#              hex_id    centile
# 0   841f905ffffffff  45.255474
# 1   841f929ffffffff  51.616267
# 2   841f92bffffffff  77.163712
# 3   841f941ffffffff  47.758081
# 4   841f945ffffffff  63.295099
# ..              ...        ...
# 66  85396507fffffff  16.058394
# 67  85396517fffffff  62.043796
# 68  85396533fffffff  15.328467
# 69  85396587fffffff  33.576642
# 70  8539658ffffffff  11.678832
#
# [71 rows x 2 columns]

# %%
hexmap_compacted = choropleth_map(df_aggreg = dataset2010byhexid_compacted, \
                                  color_map_name = "YlOrRd", column_name = "centile")
hexmap_compacted
# Out:
# valeur min pour la couleur= 0.7299270072992701, valeur max= 98.54014598540147,             valeur moyenne= 40.97137569945218
# décompte des cellules hexagonales : 71
# /tmp/ipykernel_16868/793647984.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   custom_cm = matplotlib.cm.get_cmap(color_map_name)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04f15486fad25173bb038c5669d483e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04f15486fad25173bb038c5669d483e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04f15486fad25173bb038c5669d483e2 = L.map(
#                 &quot;map_04f15486fad25173bb038c5669d483e2&quot;,
#                 {
#                     center: [47.0, 4.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d28d631164daeaa5b3afef540cfa6a55 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_d28d631164daeaa5b3afef540cfa6a55.addTo(map_04f15486fad25173bb038c5669d483e2);
#
#         function geo_json_7ca2476735e721d4a325d39888fb15dc_styler(feature) {
#             switch(feature.id) {
#                 case &quot;841f905ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd9a42&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f929ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8239&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f92bffffffff&quot;: case &quot;841f963ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9131f&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f941ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd923e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f945ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f94828&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f947ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d00d21&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f961ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd9d43&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f967ffffffff&quot;: case &quot;851f964bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb852&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;841f96bffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bb0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;843965bffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd6e33&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186da3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee084&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186da7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee187&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186db3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fec05b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186db7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#800026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186dbbfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fffecb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f906bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#990026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f907bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fff0a8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &

# %% [markdown]
# # Superposition des 2 cartes

# %%
both_hexmaps = choropleth_map(df_aggreg = dataset2010byhexid_compacted, \
                              column_name = "centile", color_map_name = "Greens",\
    fill_opacity = 0.4, initial_map = hexmap)
both_hexmaps
# Out:
# valeur min pour la couleur= 0.7299270072992701, valeur max= 98.54014598540147,             valeur moyenne= 40.97137569945218
# décompte des cellules hexagonales : 71
# /tmp/ipykernel_16868/793647984.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   custom_cm = matplotlib.cm.get_cmap(color_map_name)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fdceaecc6456d238ab0b932f77901fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fdceaecc6456d238ab0b932f77901fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fdceaecc6456d238ab0b932f77901fe = L.map(
#                 &quot;map_2fdceaecc6456d238ab0b932f77901fe&quot;,
#                 {
#                     center: [47.0, 4.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a175be28472d6c87310bd8c935ba3aa5 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a175be28472d6c87310bd8c935ba3aa5.addTo(map_2fdceaecc6456d238ab0b932f77901fe);
#
#         function geo_json_e2fd421172b8e1220fac51ef611af882_styler(feature) {
#             switch(feature.id) {
#                 case &quot;851f96abfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#800026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96affffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#820026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;85186db7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#860026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f96a3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8a0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f946bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8d0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f92abfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#910026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9403fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#950026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9633fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#990026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;853965a3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9d0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f906bfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9f0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9623fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a20026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9637fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a60026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f90c3fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#aa0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f962ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ae0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f946ffffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b20026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f90dbfffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b60026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f92a7fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b90026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;851f9463fffffff&quot;:
#                     return {&quot;color

# %% [markdown]
# # Références web

# %%
# l'Hexagone in Hexagons; Jens Andersson 2021; https://jens-wirelesscar.medium.com/

# dataset from Arthur Charpentier's post at
#  https://freakonometrics.hypotheses.org/1125
# and specifically the CSV file at
#  http://freakonometrics.free.fr/popfr19752010.csv
# population for many different years for French "communes" (regional areas) with center points for each commune

# h3 plot helper functions with Folium from Abdullah Kurkcu's blog post at
#  https://betterprogramming.pub/playing-with-ubers-hexagonal-hierarchical-spatial-index-h3-ed8d5cd7739d
